# %%
from math import pi
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
task1 = pd.read_csv('BeginState.csv')
task1 = task1.drop(0)
for col in task1.columns:
    task1[col] = [i if type(i) != type('a') else np.float64('.'.join(i.split(','))) for i in task1[col]]

# %%
x = np.array(task1['Частота'])
y = np.array(task1['Канал A'])

plt.plot(x, y)
plt.show()
