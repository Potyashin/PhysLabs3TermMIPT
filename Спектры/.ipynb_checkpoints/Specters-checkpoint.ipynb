# %%
from math import pi
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d
# %matplotlib inline

# %%
def open_csv(name):
    file = pd.read_csv(name)
    file = file.drop(0)
    for col in file.columns:
        file[col] = [np.float64(i) for i in file[col]]
    return file

# %%
# Начальное состояние
begin_state = open_csv('BeginState.csv')
freqX2 = open_csv('FrequencyX2.csv')
timeX2 = open_csv('TimeX2.csv')

# %%
# Строим график
x = np.array(begin_state['Частота'])  
y = np.array(begin_state['Канал A'])
plt.plot(x,y)
plt.show()

# %%
# Строим график
x = np.array(freqX2['Частота'])  
y = np.array(freqX2['Канал A'])
plt.plot(x,y)
plt.show()

# %%
# Строим график
x = np.array(timeX2['Частота'])  
y = np.array(timeX2['Канал A'])
plt.plot(x,y)
plt.show()

# %%
point8 = open_csv('point_8/80us.csv')
# Строим график
x = np.array(point8['Частота'])  
y = np.array(point8['Канал A'])
plt.plot(x,y)
plt.show()
